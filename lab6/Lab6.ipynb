# %% [markdown]
# # Lab 6 - Gaussian Process

# %%
from cmdstanpy import CmdStanModel

import arviz as az
import numpy as np
import scipy.stats as stats

import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# In general, Gaussian Process (GP) is a stochastic process used for modeling data, which were observed over time, space or both. Main thing that can characterise GP is that is a kind of generalization of normal probability distributions, where each of them describes a random variable (scalar or vector if we deal with multivariate distribution).
#
# Following definition captures the essence of Gaussian Process:
#
# A Gaussian process is a collection of random variables, any Gaussian process finite number of which have a joint Gaussian distribution.
#
#
# If we define mean function $m(x)$ and the covariance function mean function $k(x,x')$ of a real process $f(x)$ as:
# \begin{equation}
# m(x) = E[f(x)]
# \end{equation}
# \begin{equation}
# k(x,x') = E[f(x)-m(x))(f(x')-m(x'))]
# \end{equation}
# Then we can define GP can as:
# \begin{equation}
# \label{eq:gpmain}
# f(x) \sim GP(m(x),k(x,x'))
# \end{equation}
#
#
# GP can be fully determined by only declaring mean and covariance functions. Mean in most cases is set to value "0", because such a setting can be useful, simplifies matters and is not a difficult requirement to fulfill. Of course, there are examples
# where we would like to change the mean e.g. for better model interpretability or the
# specification of our prior. Covariance function (also called kernel function) represents
# a similarity between data points. Note that usually covariance is chosen from
# the set of already defined functions. The one should at least pick one, which represents
# prior beliefs of the problem. But in fact, covariance function can be any function, which
# has the property of generating a positive definite covariance matrix. Anyway, creating
# and defining new covariance functions, which will simultaneously be correct and have a
# practical usage, can be really difficult
#
# The most basic and common kernel function is Radial Basis Function (RBF), which is defined with the formula:
# \begin{equation}
# \label{eq:rbf}
# k\left(x_{i}, x_{j}\right)=\exp \left(-\frac{d\left(x_{i}, x_{j}\right)^{2}}{2 l^{2}}\right)
# \end{equation}
# Its main property is that its value is usually only dependent on the distance from the specified point. The parameter which RBF kernel uses is $l$ as a characteristic length scale. RBF is infinitely differentiable. That means the GP with this kernel has a mean square derivatives for all orders. Other worth noting kernel, in terms of our classess is one from exponentiated quadratic family, where $\rho$ is length-scale and $\alpha$ is marginal deviation:
# $$
# k\left(x_{1}, x_{2}\right)=\alpha^{2} \exp \left(-\frac{1}{2}\left(\frac{\left|x_{1}-x_{2}\right|}{\rho}\right)^{2}\right)
# $$
# Gaussian Process is growing in popularity of usage in domains connected with statistics and machine learning. It is especially efficient solution, while we are dealing with a problem of obtaining data e.g. for faulty cases or just an overall lack of comprehensive data and if we want to obtain not only prediction but also confidence interval. Main areas where GP is used for are: regression, prediction, classification and identification. On this classes we will focuse on a simple task of regression.

# %% [markdown]
# ### Task 1: simulating from Gaussian Process model

# %% [markdown]
# To make any simulations, first you need a set of observations:

# %%
#Observed data
x_obs = [-10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10]
y_obs = [0.328572824089476, 4.20607004111644, 1.35507551134795,
0.161608755204364, -5.42320349780782, -3.05851276224202, -0.0764172642034502,
-4.55218472276499, -0.902226297922731, -5.8609833528976, -1.05854090910473]

# %% [markdown]
# Model also needs sampling space and the indexes of where our observed data resides there.
# For your convenience, we provide them below:

# %%
x_predict = np.linspace(-11,11,551,endpoint=True)
observed_idx = [26, 76, 126, 176, 226, 276, 326, 376, 426, 476, 526]

# %% [markdown]
# In this example we are using kernel from exponentiated quadratic family, so we need to provide its hyperparameters (alpha and rho). Moreover, for sample generation, we would like to set a sigma value. Let's start with some arbitrarily selected parameters:

# %%
alpha = 3
rho = 5.5
sigma = 2

alpha2 = 8
rho2 = 8
sigma2 = 8

alpha3 = 1
rho3 = 0.5
sigma3 = 2

# %% [markdown]
# Now we can create a model and sample from it. Do not forget to define proper data value based on requirements from stan model.

# %%
model = CmdStanModel(stan_file='D:\Studia\MAGISTERKA\semestr_1\data_analytics\lab6\gaussian_process.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
data = {'N_predict':len(x_predict),
        'x_predict':x_predict,
        'N_obs':len(y_obs),
        'y_obs':y_obs,
        'observed_idx':observed_idx,
        'rho':rho,
        'alpha':alpha,
        'sigma':sigma}
        
result = model.sample(data=data, chains = 4)
# Out:
# INFO:cmdstanpy:CmdStan start procesing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |▍         | 00:00 Status
#
#
# chain 1 |▉         | 00:02 Iteration:    1 / 2000 [  0%]  (Warmup)
#
#
# chain 1 |█▎        | 00:05 Iteration:  100 / 2000 [  5%]  (Warmup)
#
#
# chain 1 |█▊        | 00:07 Iteration:  200 / 2000 [ 10%]  (Warmup)
#
#
# chain 1 |██▎       | 00:10 Iteration:  300 / 2000 [ 15%]  (Warmup)
#
#
# chain 1 |██▋       | 00:12 Iteration:  400 / 2000 [ 20%]  (Warmup)
#
#
# chain 1 |███▏      | 00:15 Iteration:  500 / 2000 [ 25%]  (Warmup)
#
#
# chain 1 |███▋      | 00:17 Iteration:  600 / 2000 [ 30%]  (Warmup)
#
#
# chain 1 |████      | 00:19 Iteration:  700 / 2000 [ 35%]  (Warmup)
#
#
# chain 1 |████▌     | 00:21 Iteration:  800 / 2000 [ 40%]  (Warmup)
#
#
# chain 1 |█████     | 00:23 Iteration:  900 / 2000 [ 45%]  (Warmup)
#
#
# chain 1 |█████▉    | 00:25 Iteration: 1001 / 2000 [ 50%]  (Sampling)
#
#
# chain 1 |██████▎   | 00:28 Iteration: 1100 / 2000 [ 55%]  (Sampling)
#
#
# chain 1 |██████▊   | 00:30 Iteration: 1200 / 2000 [ 60%]  (Sampling)
#
#
# chain 1 |███████▎  | 00:32 Iteration: 1300 / 2000 [ 65%]  (Sampling)
#
#
# chain 1 |███████▋  | 00:34 Iteration: 1400 / 2000 [ 70%]  (Sampling)
#
#
# chain 1 |████████▏ | 00:36 Iteration: 1500 / 2000 [ 75%]  (Sampling)
#
#
# chain 1 |████████▋ | 00:38 Iteration: 1600 / 2000 [ 80%]  (Sampling)
#
#
# chain 1 |█████████ | 00:40 Iteration: 1700 / 2000 [ 85%]  (Sampling)
#
#
# chain 1 |█████████▌| 00:42 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
#
# chain 1 |██████████| 00:45 Iteration: 1900 / 2000 [ 95%]  (Sampling)
#
#
# chain 1 |██████████| 00:46 Sampling completed
# chain 2 |██████████| 00:46 Sampling completed
# chain 3 |██████████| 00:46 Sampling completed
# chain 4 |██████████| 00:46 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %% [markdown]
# Your task now is to:
# - plot few (about 5-10) samples generated from model
# - plot mean value from model with its confidence interval (standar deviation, using errorbar function)
#
# Also on each plot place points with obsserved data. Repeat the steps for two other parameters sets of your choice

# %%
y_predict = result.stan_variable('y_predict')
mean_y = []
for y in y_predict:
    mean_y.append(np.mean(y))

fig, ax = plt.subplots(2,3,figsize=(10,5))
ax[0][0].plot(y_predict[0])
ax[0][0].plot(observed_idx, y_obs, '*m')
ax[0][0].legend(['Sample','Observed'])
ax[0][0].grid()
ax[0][1].plot(y_predict[1])
ax[0][1].plot(observed_idx, y_obs, '*m')
ax[0][1].legend(['Sample','Observed'])
ax[0][1].grid()
ax[0][2].plot(y_predict[2])
ax[0][2].plot(observed_idx, y_obs, '*m')
ax[0][2].legend(['Sample','Observed'])
ax[0][2].grid()
ax[1][0].plot(y_predict[3])
ax[1][0].plot(observed_idx, y_obs, '*m')
ax[1][0].legend(['Sample','Observed'])
ax[1][0].grid()
ax[1][1].plot(y_predict[4])
ax[1][1].plot(observed_idx, y_obs, '*m')
ax[1][1].legend(['Sample','Observed'])
ax[1][1].grid()
ax[1][2].errorbar(x_predict[0:50],mean_y[0:50],0.5,0.02)
ax[1][2].grid()

# %%
data2 = {'N_predict':len(x_predict),
        'x_predict':x_predict,
        'N_obs':len(y_obs),
        'y_obs':y_obs,
        'observed_idx':observed_idx,
        'rho':rho2,
        'alpha':alpha2,
        'sigma':sigma2}
        
result2 = model.sample(data=data2, chains = 4)
# Out:
# INFO:cmdstanpy:CmdStan start procesing
# chain 1 |          | 00:00 Status
#
#
#
#
#
# chain 1 |▍         | 00:00 Status
#
#
# chain 1 |▉         | 00:02 Iteration:    1 / 2000 [  0%]  (Warmup)
#
#
# chain 1 |█▎        | 00:05 Iteration:  100 / 2000 [  5%]  (Warmup)
#
#
# chain 1 |█▊        | 00:08 Iteration:  200 / 2000 [ 10%]  (Warmup)
#
#
# chain 1 |██▎       | 00:11 Iteration:  300 / 2000 [ 15%]  (Warmup)
#
#
# chain 1 |██▋       | 00:14 Iteration:  400 / 2000 [ 20%]  (Warmup)
#
#
# chain 1 |███▏      | 00:16 Iteration:  500 / 2000 [ 25%]  (Warmup)
#
#
# chain 1 |███▋      | 00:18 Iteration:  600 / 2000 [ 30%]  (Warmup)
#
#
# chain 1 |████      | 00:21 Iteration:  700 / 2000 [ 35%]  (Warmup)
#
#
# chain 1 |████▌     | 00:23 Iteration:  800 / 2000 [ 40%]  (Warmup)
#
#
# chain 1 |█████     | 00:25 Iteration:  900 / 2000 [ 45%]  (Warmup)
#
#
# chain 1 |█████▉    | 00:27 Iteration: 1001 / 2000 [ 50%]  (Sampling)
#
#
# chain 1 |██████▎   | 00:29 Iteration: 1100 / 2000 [ 55%]  (Sampling)
#
#
# chain 1 |██████▊   | 00:31 Iteration: 1200 / 2000 [ 60%]  (Sampling)
#
#
# chain 1 |███████▎  | 00:33 Iteration: 1300 / 2000 [ 65%]  (Sampling)
#
#
# chain 1 |███████▋  | 00:35 Iteration: 1400 / 2000 [ 70%]  (Sampling)
#
#
# chain 1 |████████▏ | 00:37 Iteration: 1500 / 2000 [ 75%]  (Sampling)
#
#
# chain 1 |████████▋ | 00:40 Iteration: 1600 / 2000 [ 80%]  (Sampling)
#
#
# chain 1 |█████████ | 00:42 Iteration: 1700 / 2000 [ 85%]  (Sampling)
#
#
# chain 1 |█████████▌| 00:44 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
#
# chain 1 |██████████| 00:45 Sampling completed
# chain 2 |██████████| 00:45 Sampling completed
# chain 3 |██████████| 00:45 Sampling completed
# chain 4 |██████████| 00:45 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
y_predict2 = result2.stan_variable('y_predict')
mean_y2 = []
for y in y_predict2:
    mean_y2.append(np.mean(y))

fig, ax = plt.subplots(2,3,figsize=(10,5))
ax[0][0].plot(y_predict2[0])
ax[0][0].plot(observed_idx, y_obs, '*m')
ax[0][0].legend(['Sample','Observed'])
ax[0][0].grid()
ax[0][1].plot(y_predict2[1])
ax[0][1].plot(observed_idx, y_obs, '*m')
ax[0][1].legend(['Sample','Observed'])
ax[0][1].grid()
ax[0][2].plot(y_predict2[2])
ax[0][2].plot(observed_idx, y_obs, '*m')
ax[0][2].legend(['Sample','Observed'])
ax[0][2].grid()
ax[1][0].plot(y_predict2[3])
ax[1][0].plot(observed_idx, y_obs, '*m')
ax[1][0].legend(['Sample','Observed'])
ax[1][0].grid()
ax[1][1].plot(y_predict2[4])
ax[1][1].plot(observed_idx, y_obs, '*m')
ax[1][1].legend(['Sample','Observed'])
ax[1][1].grid()
ax[1][2].errorbar(x_predict[0:50],mean_y2[0:50],0.5,0.02)
ax[1][2].grid()

# %%
data3 = {'N_predict':len(x_predict),
        'x_predict':x_predict,
        'N_obs':len(y_obs),
        'y_obs':y_obs,
        'observed_idx':observed_idx,
        'rho':rho3,
        'alpha':alpha3,
        'sigma':sigma3}
        
result3 = model.sample(data=data3, chains = 4)
# Out:
# INFO:cmdstanpy:CmdStan start procesing
# chain 1 |          | 00:00 Status
#
#
#
#
#
# chain 1 |▍         | 00:00 Status
#
#
# chain 1 |▉         | 00:02 Iteration:    1 / 2000 [  0%]  (Warmup)
#
#
# chain 1 |█▎        | 00:04 Iteration:  100 / 2000 [  5%]  (Warmup)
#
#
# chain 1 |█▊        | 00:07 Iteration:  200 / 2000 [ 10%]  (Warmup)
#
#
# chain 1 |██▎       | 00:09 Iteration:  300 / 2000 [ 15%]  (Warmup)
#
#
# chain 1 |██▋       | 00:11 Iteration:  400 / 2000 [ 20%]  (Warmup)
#
#
# chain 1 |███▏      | 00:14 Iteration:  500 / 2000 [ 25%]  (Warmup)
#
#
#
# chain 1 |███▋      | 00:16 Iteration:  600 / 2000 [ 30%]  (Warmup)
#
#
#
#
# chain 1 |████      | 00:18 Iteration:  700 / 2000 [ 35%]  (Warmup)
# chain 1 |████▌     | 00:20 Iteration:  800 / 2000 [ 40%]  (Warmup)
#
# chain 1 |█████     | 00:21 Iteration:  900 / 2000 [ 45%]  (Warmup)
#
#
# chain 1 |█████▉    | 00:23 Iteration: 1001 / 2000 [ 50%]  (Sampling)
#
#
# chain 1 |██████▎   | 00:25 Iteration: 1100 / 2000 [ 55%]  (Sampling)
#
#
# chain 1 |██████▊   | 00:28 Iteration: 1200 / 2000 [ 60%]  (Sampling)
#
#
#
# chain 1 |███████▎  | 00:30 Iteration: 1300 / 2000 [ 65%]  (Sampling)
#
#
# chain 1 |███████▋  | 00:32 Iteration: 1400 / 2000 [ 70%]  (Sampling)
#
#
# chain 1 |████████▏ | 00:34 Iteration: 1500 / 2000 [ 75%]  (Sampling)
#
#
# chain 1 |████████▋ | 00:36 Iteration: 1600 / 2000 [ 80%]  (Sampling)
#
#
# chain 1 |█████████ | 00:38 Iteration: 1700 / 2000 [ 85%]  (Sampling)
#
#
# chain 1 |█████████▌| 00:40 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
# chain 1 |██████████| 00:41 Sampling completed
# chain 2 |██████████| 00:41 Sampling completed
# chain 3 |██████████| 00:41 Sampling completed
# chain 4 |██████████| 00:41 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
y_predict3 = result3.stan_variable('y_predict')
mean_y3 = []
for y in y_predict3:
    mean_y3.append(np.mean(y))

fig, ax = plt.subplots(2,3,figsize=(10,5))
ax[0][0].plot(y_predict3[0])
ax[0][0].plot(observed_idx, y_obs, '*m')
ax[0][0].legend(['Sample','Observed'])
ax[0][0].grid()
ax[0][1].plot(y_predict3[1])
ax[0][1].plot(observed_idx, y_obs, '*m')
ax[0][1].legend(['Sample','Observed'])
ax[0][1].grid()
ax[0][2].plot(y_predict3[2])
ax[0][2].plot(observed_idx, y_obs, '*m')
ax[0][2].legend(['Sample','Observed'])
ax[0][2].grid()
ax[1][0].plot(y_predict3[3])
ax[1][0].plot(observed_idx, y_obs, '*m')
ax[1][0].legend(['Sample','Observed'])
ax[1][0].grid()
ax[1][1].plot(y_predict3[4])
ax[1][1].plot(observed_idx, y_obs, '*m')
ax[1][1].legend(['Sample','Observed'])
ax[1][1].grid()
ax[1][2].errorbar(x_predict[0:50],mean_y3[0:50],0.5,0.02)
ax[1][2].grid()

# %% [markdown]
# ### Task 2: optimize hyperparameters

# %% [markdown]
# To achive better results of GP fitting for our observed data, we need to oprimize its parameters. We can do that by using maximum marginal likelihood estimation. It can be done by placing parameters in "parameter" block in stan model and using "optimize" method.

# %%
model2 = CmdStanModel(stan_file='D:\Studia\MAGISTERKA\semestr_1\data_analytics\lab6\gaussian_process_optimize.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
data4 = {'N_obs':len(y_obs),
        'x_obs':x_obs,
        'y_obs':y_obs
}
result4 = model2.optimize(data=data4, seed=5838298)
# Out:
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# Optimize parameters with mentioned method and generate new samples with model from task 1. Of course use just aquired parameters. Do not forget to specify data variable based on stan model.
# What can your say about results in comparison to ones from task 1?
# Did the GP perform well in the task of regression?

# %%
rho4 = result4.stan_variable('rho')
alpha4 = result4.stan_variable('alpha')
sigma4 = result4.stan_variable('sigma')

data5 = data = {'N_predict':len(x_predict),
        'x_predict':x_predict,
        'N_obs':len(y_obs),
        'y_obs':y_obs,
        'observed_idx':observed_idx,
        'rho':rho4,
        'alpha':alpha4,
        'sigma':sigma4}

result5 = model.sample(data=data5, chains=4)
# Out:
# INFO:cmdstanpy:CmdStan start procesing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |▍         | 00:00 Status
#
#
# chain 1 |▉         | 00:14 Iteration:    1 / 2000 [  0%]  (Warmup)
#
#
# chain 1 |█▎        | 00:29 Iteration:  100 / 2000 [  5%]  (Warmup)
#
#
# chain 1 |█▊        | 00:44 Iteration:  200 / 2000 [ 10%]  (Warmup)
#
#
# chain 1 |██▎       | 00:56 Iteration:  300 / 2000 [ 15%]  (Warmup)
#
#
# chain 1 |██▋       | 01:10 Iteration:  400 / 2000 [ 20%]  (Warmup)
#
#
# chain 1 |███▏      | 01:22 Iteration:  500 / 2000 [ 25%]  (Warmup)
#
#
# chain 1 |███▋      | 01:33 Iteration:  600 / 2000 [ 30%]  (Warmup)
# chain 1 |████      | 01:43 Iteration:  700 / 2000 [ 35%]  (Warmup)
#
#
# chain 1 |████▌     | 01:54 Iteration:  800 / 2000 [ 40%]  (Warmup)
#
#
# chain 1 |█████     | 02:07 Iteration:  900 / 2000 [ 45%]  (Warmup)
#
#
#
# chain 1 |█████▉    | 02:16 Iteration: 1001 / 2000 [ 50%]  (Sampling)
#
#
#
# chain 1 |██████▎   | 02:26 Iteration: 1100 / 2000 [ 55%]  (Sampling)
# chain 1 |██████▊   | 02:35 Iteration: 1200 / 2000 [ 60%]  (Sampling)
#
#
# chain 1 |███████▋  | 02:54 Iteration: 1400 / 2000 [ 70%]  (Sampling)
#
#
# chain 1 |████████▏ | 03:03 Iteration: 1500 / 2000 [ 75%]  (Sampling)
# chain 1 |████████▋ | 03:12 Iteration: 1600 / 2000 [ 80%]  (Sampling)
#
# chain 1 |█████████ | 03:21 Iteration: 1700 / 2000 [ 85%]  (Sampling)
# chain 1 |█████████▌| 03:31 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
#
# chain 1 |██████████| 03:41 Iteration: 1900 / 2000 [ 95%]  (Sampling)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chain 1 |██████████| 04:20 Sampling completed
# chain 2 |██████████| 04:20 Sampling completed
# chain 3 |██████████| 04:20 Sampling completed
# chain 4 |██████████| 04:20 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
y_predict4 = result5.stan_variable('y_predict')
mean_y4 = []
for y in y_predict3:
    mean_y4.append(np.mean(y))

fig, ax = plt.subplots(2,3,figsize=(10,5))
ax[0][0].plot(y_predict4[0])
ax[0][0].plot(observed_idx, y_obs, '*m')
ax[0][0].legend(['Sample','Observed'])
ax[0][0].grid()
ax[0][1].plot(y_predict4[1])
ax[0][1].plot(observed_idx, y_obs, '*m')
ax[0][1].legend(['Sample','Observed'])
ax[0][1].grid()
ax[0][2].plot(y_predict4[2])
ax[0][2].plot(observed_idx, y_obs, '*m')
ax[0][2].legend(['Sample','Observed'])
ax[0][2].grid()
ax[1][0].plot(y_predict4[3])
ax[1][0].plot(observed_idx, y_obs, '*m')
ax[1][0].legend(['Sample','Observed'])
ax[1][0].grid()
ax[1][1].plot(y_predict4[4])
ax[1][1].plot(observed_idx, y_obs, '*m')
ax[1][1].legend(['Sample','Observed'])
ax[1][1].grid()
ax[1][2].errorbar(x_predict[0:50],mean_y4[0:50],0.2,0.001)
ax[1][2].grid()
